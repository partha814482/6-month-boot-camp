# %%
import pandas as pd

# %%
emp = pd.read_excel(r"C:\Users\HP\Downloads\give me some raw data to clean the data in excel....xlsx")

# %%
emp
# Out:
#    OrderID   CustomerName      Product Quantity    Price            OrderDate  \
# 0    A1001     John Smith       Laptop        1  1200.50  2023-01-15 00:00:00
# 1    A1002       Jane doe    m-o-u-s-e        2    25.00  2023-01-16 00:00:00
# 2    A1003    Peter Jones     Keyboard      one    75.25  2023-01-17 00:00:00
# 3    A1004     John Smith      Monitor        1   250.00  2023-01-18 00:00:00
# 4    A1005       Mary Lee       Webcam        1    50.00             20230119
# 5    A1006     Sarah Chen  Headphoness        3   150.00  2023-01-20 00:00:00
# 6    A1007   David Wilson       Laptop        1  1200.50  2023-01-21 00:00:00
# 7    A1008       Jane Doe        Mouse        1    25.00  2023-01-22 00:00:00
# 8    A1009   Laura Garcia      Speaker        2    80.00  2023-01-23 00:00:00
# 9    A1010    Chris Evans     Keyboard        1    75.25  2023-01-24 00:00:00
# 10   A1011  Michael Davis        Mouse        1    25.00  2023-01-25 00:00:00
# ...

# %%
emp.shape
# Out:
# (15, 8)

# %%
emp.dtypes
# Out:
# OrderID            object
# CustomerName       object
# Product            object
# Quantity           object
# Price             float64
# OrderDate          object
# ShippingStatus     object
# Email              object
# dtype: object

# %%
emp.isnull()
# Out:
#     OrderID  CustomerName  Product  Quantity  Price  OrderDate  \
# 0     False         False    False     False  False      False
# 1     False         False    False     False  False      False
# 2     False         False    False     False  False      False
# 3     False         False    False     False  False      False
# 4     False         False    False     False  False      False
# 5     False         False    False     False  False      False
# 6     False         False    False     False  False      False
# 7     False         False    False     False  False      False
# 8     False         False    False     False  False      False
# 9     False         False    False     False  False      False
# 10    False         False    False     False  False      False
# 11    False         False    False     False  False      False
# 12    False         False    False     False  False      False
# 13    False         False    False     False  False      False
# ...

# %%
emp.isnull().sum()
# Out:
# OrderID           0
# CustomerName      0
# Product           0
# Quantity          0
# Price             0
# OrderDate         0
# ShippingStatus    0
# Email             0
# dtype: int64

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OrderID         15 non-null     object
#  1   CustomerName    15 non-null     object
#  2   Product         15 non-null     object
#  3   Quantity        15 non-null     object
#  4   Price           15 non-null     float64
#  5   OrderDate       15 non-null     object
#  6   ShippingStatus  15 non-null     object
#  7   Email           15 non-null     object
# dtypes: float64(1), object(7)
# memory usage: 1.1+ KB

# %%
emp.head()
# Out:
#   OrderID CustomerName    Product Quantity    Price            OrderDate  \
# 0   A1001   John Smith     Laptop        1  1200.50  2023-01-15 00:00:00
# 1   A1002     Jane doe  m-o-u-s-e        2    25.00  2023-01-16 00:00:00
# 2   A1003  Peter Jones   Keyboard      one    75.25  2023-01-17 00:00:00
# 3   A1004   John Smith    Monitor        1   250.00  2023-01-18 00:00:00
# 4   A1005     Mary Lee     Webcam        1    50.00             20230119
#
#   ShippingStatus                 Email
# 0        Shipped  john.smith@email.com
# 1        Pending    jane_doe@email.com
# 2      Delivered     P.JONES@email.com
# 3        SHIPPED  john.smith@email.com
# 4      Delivered    mary.lee@email.com

# %%
emp['OrderID']
# Out:
# 0     A1001
# 1     A1002
# 2     A1003
# 3     A1004
# 4     A1005
# 5     A1006
# 6     A1007
# 7     A1008
# 8     A1009
# 9     A1010
# 10    A1011
# 11    A1012
# 12    A1013
# 13    A1014
# 14    A1015
# Name: OrderID, dtype: object

# %%
emp['Product']
# Out:
# 0          Laptop
# 1       m-o-u-s-e
# 2        Keyboard
# 3         Monitor
# 4          Webcam
# 5     Headphoness
# 6          Laptop
# 7           Mouse
# 8         Speaker
# 9        Keyboard
# 10          Mouse
# 11        Monitor
# 12         webcam
# 13         Laptop
# 14     Headphones
# Name: Product, dtype: object

# %%
emp['Product'] = emp['Product'].str.replace('r\W','',regex=True)

# %%
emp['Product']
# Out:
# 0          Laptop
# 1       m-o-u-s-e
# 2        Keyboard
# 3         Monitor
# 4          Webcam
# 5     Headphoness
# 6          Laptop
# 7           Mouse
# 8         Speaker
# 9        Keyboard
# 10          Mouse
# 11        Monitor
# 12         webcam
# 13         Laptop
# 14     Headphones
# Name: Product, dtype: object

# %%
#emp['Product'] = emp['Product'].str.extract('(\\d+)')

# %%
#emp['Product']

# %%
emp['Product']
# Out:
# 0          Laptop
# 1       m-o-u-s-e
# 2        Keyboard
# 3         Monitor
# 4          Webcam
# 5     Headphoness
# 6          Laptop
# 7           Mouse
# 8         Speaker
# 9        Keyboard
# 10          Mouse
# 11        Monitor
# 12         webcam
# 13         Laptop
# 14     Headphones
# Name: Product, dtype: object

# %%
emp['Email']
# Out:
# 0        john.smith@email.com
# 1          jane_doe@email.com
# 2           P.JONES@email.com
# 3        john.smith@email.com
# 4          mary.lee@email.com
# 5        sarah.chen@email.com
# 6          d.wilson@email.com
# 7          jane_doe@email.com
# 8           laura.g@email.com
# 9           chris.e@email.com
# 10    michael.davis@email.com
# 11          o.brown@email.com
# 12         mary.lee@email.com
# 13          p.jones@email.com
# 14       sarah.chen@email.com
# Name: Email, dtype: object

# %%
emp['Email'] = emp['Email'].str.replace(r'\W','',regex=True)

# %%
emp['Email']
# Out:
# 0        johnsmithemailcom
# 1         jane_doeemailcom
# 2           PJONESemailcom
# 3        johnsmithemailcom
# 4          maryleeemailcom
# 5        sarahchenemailcom
# 6          dwilsonemailcom
# 7         jane_doeemailcom
# 8           lauragemailcom
# 9           chriseemailcom
# 10    michaeldavisemailcom
# 11          obrownemailcom
# 12         maryleeemailcom
# 13          pjonesemailcom
# 14       sarahchenemailcom
# Name: Email, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = 6,2

# %%
emp
# Out:
#    OrderID   CustomerName      Product Quantity    Price            OrderDate  \
# 0    A1001     John Smith       Laptop        1  1200.50  2023-01-15 00:00:00
# 1    A1002       Jane doe    m-o-u-s-e        2    25.00  2023-01-16 00:00:00
# 2    A1003    Peter Jones     Keyboard      one    75.25  2023-01-17 00:00:00
# 3    A1004     John Smith      Monitor        1   250.00  2023-01-18 00:00:00
# 4    A1005       Mary Lee       Webcam        1    50.00             20230119
# 5    A1006     Sarah Chen  Headphoness        3   150.00  2023-01-20 00:00:00
# 6    A1007   David Wilson       Laptop        1  1200.50  2023-01-21 00:00:00
# 7    A1008       Jane Doe        Mouse        1    25.00  2023-01-22 00:00:00
# 8    A1009   Laura Garcia      Speaker        2    80.00  2023-01-23 00:00:00
# 9    A1010    Chris Evans     Keyboard        1    75.25  2023-01-24 00:00:00
# 10   A1011  Michael Davis        Mouse        1    25.00  2023-01-25 00:00:00
# ...

# %%
vis1 = sns.distplot(emp['Price'])

# %%
plt.show()

# %%
emp
# Out:
#    OrderID   CustomerName      Product Quantity    Price            OrderDate  \
# 0    A1001     John Smith       Laptop        1  1200.50  2023-01-15 00:00:00
# 1    A1002       Jane doe    m-o-u-s-e        2    25.00  2023-01-16 00:00:00
# 2    A1003    Peter Jones     Keyboard      one    75.25  2023-01-17 00:00:00
# 3    A1004     John Smith      Monitor        1   250.00  2023-01-18 00:00:00
# 4    A1005       Mary Lee       Webcam        1    50.00             20230119
# 5    A1006     Sarah Chen  Headphoness        3   150.00  2023-01-20 00:00:00
# 6    A1007   David Wilson       Laptop        1  1200.50  2023-01-21 00:00:00
# 7    A1008       Jane Doe        Mouse        1    25.00  2023-01-22 00:00:00
# 8    A1009   Laura Garcia      Speaker        2    80.00  2023-01-23 00:00:00
# 9    A1010    Chris Evans     Keyboard        1    75.25  2023-01-24 00:00:00
# 10   A1011  Michael Davis        Mouse        1    25.00  2023-01-25 00:00:00
# ...

# %%
vis2 = sns.boxplot(data = emp, x = 'Quantity', y = 'Price')

# %%
plt.show()

# %%
vis1 = sns.boxplot(data = emp,x =price , y = Quality)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 vis1 = sns.boxplot(data = emp,x =price , y = Quality)
#
# NameError: name 'price' is not defined

# %%
vis2 = sns.boxplot(data = emp, y = 'Quantity', x = 'Price')

# %%
plt.show()

# %%
vis2 = sns.lmplot(data = emp, x = 'Quantity', y = 'Price')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 vis2 = sns.lmplot(data = emp, x = 'Quantity', y = 'Price')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\regression.py:640, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     637     ax.update_datalim(xys, updatey=False)
#     638     ax.autoscale_view(scaley=False)
# --> 640 facets.map_dataframe(update_datalim, x=x, y=y)
#     642 # Draw the regression plot on each facet
#     643 regplot_kws = dict(
#     644     x_estimator=x_estimator, x_bins=x_bins, x_ci=x_ci,
# ...
