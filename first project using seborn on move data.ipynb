# %% [markdown]
# MOVIE RATING ANALYTICS   (ADVANCE VISULIZATION)

# %%
import pandas as pd

# %%
movies = pd.read_csv(r"C:\Users\HP\OneDrive\Documents\SENAPATI SIR FSDS NOTE\SEPTMBER MONTH DS NOTE\3rd - MOVIE RATING_ADVANCE VISUALIZATION\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.hist()
# Out:
# array([[<Axes: title={'center': 'Rotten Tomatoes Ratings %'}>,
#         <Axes: title={'center': 'Audience Ratings %'}>],
#        [<Axes: title={'center': 'Budget (million $)'}>,
#         <Axes: title={'center': 'Year of release'}>]], dtype=object)

# %%
len(movies)
# Out:
# 559

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.isnull()
# Out:
#       Film  Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 0    False  False                      False               False
# 1    False  False                      False               False
# 2    False  False                      False               False
# 3    False  False                      False               False
# 4    False  False                      False               False
# ..     ...    ...                        ...                 ...
# 554  False  False                      False               False
# 555  False  False                      False               False
# 556  False  False                      False               False
# 557  False  False                      False               False
# 558  False  False                      False               False
#
#      Budget (million $)  Year of release
# 0                 False            False
# 1                 False            False
# 2                 False            False
# ...

# %%
movies.isnull().sum()
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.head(1)
# Out:
#                     Film   Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer   Comedy                         87
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009

# %%
movies.columns = ['Film','Genre','CriticRating','AudianceRating','BudgetMillions','Year']

# %%
movies.head(1)
# Out:
#                     Film   Genre  CriticRating  AudianceRating  \
# 0  (500) Days of Summer   Comedy            87              81
#
#    BudgetMillions  Year
# 0               8  2009

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudianceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudianceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# if you look at the yearthe data type is int but when you look at the mean value it showing 2009 which is minning less
# we have to change to category types
# Also from object datatypes we will convert to category data types
# Out:
#        CriticRating  AudianceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies['AudianceRating']
# Out:
# 0      81
# 1      44
# 2      52
# 3      84
# 4      70
#        ..
# 554    36
# 555    52
# 556    73
# 557    87
# 558    42
# Name: AudianceRating, Length: 559, dtype: int64

# %%
movies.Film  # movies.Film == movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %% [markdown]
# we convert the object datatype to the category data type

# %%
movies.Film = movies.Film.astype('category')
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudianceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies['Year']
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudianceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
movies.describe()
# Out:
#        CriticRating  AudianceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudianceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %% [markdown]
# How to work with join plot

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data = movies,x = 'CriticRating', y = 'AudianceRating')

# %%
plt.show()

# %% [markdown]
# The above graph give AudianceRatng is more dominant then CriticRating . Based on this we find out as most pepole are most liklihood to watch audiance rating and less likely to waatch critics rating . Explain in excel- if you apply filter on AudianceRating and CriticRating --CriticRating has very low value compair to audiance rating

# %%
j = sns.jointplot(data=movies,x = 'CriticRating', y = 'AudianceRating',kind = 'scatter')

# %%
plt.show()

# %%
j = sns.jointplot(data=movies,x = 'CriticRating', y = 'AudianceRating',kind = 'reg')

# %%
plt.show()

# %%
j = sns.jointplot(data=movies,x = 'CriticRating', y = 'AudianceRating',kind = 'hex')

# %%
plt.show()

# %%
j = sns.jointplot(data=movies,x = 'CriticRating', y = 'AudianceRating',kind = 'hist')

# %%
plt.show()

# %%
j = sns.jointplot(data=movies,x = 'CriticRating', y = 'AudianceRating',kind = 'resid')

# %%
plt.show()

# %%
# histogram
m1 = sns.distplot(movies.AudianceRating)
# y-axis generated by seaborn automatically that is the powerfull of seaborn gallery 
plt.show()

# %%
movies.AudianceRating
# Out:
# 0      81
# 1      44
# 2      52
# 3      84
# 4      70
#        ..
# 554    36
# 555    52
# 556    73
# 557    87
# 558    42
# Name: AudianceRating, Length: 559, dtype: int64

# %%
sns.set_style('darkgrid') # Here set_style is used to change the background colour of the graph

# %%
# histogram
m1 = sns.distplot(movies.AudianceRating)
# y-axis generated by seaborn automatically that is the powerfull of seaborn gallery 
plt.show()

# %%
m2 = sns.distplot(movies.AudianceRating,bins=15)
plt.show()

# %%
n1 = plt.hist(movies.AudianceRating,bins=17)
plt.show()

# %%
sns.set_style('white') # normal distribution and call as bell curve
n1 = plt.hist(movies.AudianceRating,bins=17)
plt.show()

# %%
n1 = plt.hist(movies.CriticRating,bins=20) # uniform distribution
plt.show()

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudianceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
plt.hist(movies.BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'ram'].BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions,bins=20)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions,bins=20)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions,bins=20)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions,bins=20)
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions,bins=20)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions,bins=20)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions,bins=20,stacked = True)
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions,bins=20,stacked = True)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions,bins=20,stacked = True)
plt.hist(movies[movies.Genre == 'Comedy'].BudgetMillions,bins=20,stacked = True)
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Drama'].BudgetMillions,\
          movies[movies.Genre == 'Action'].BudgetMillions,\
          movies[movies.Genre == 'Thriller'].BudgetMillions,\
          movies[movies.Genre == 'Comedy'].BudgetMillions,],
          bins = 20, stacked = False)
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,\
          movies[movies.Genre == 'Drama'].BudgetMillions, \
          movies[movies.Genre == 'Thriller'].BudgetMillions, \
          movies[movies.Genre == 'Comedy'].BudgetMillions],
         bins = 20, stacked = True)
plt.show()

# %%
#if you have 100 category you can not copy and paste all these things
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudianceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
#for Films in movies.Film.cat.categories:
    #print(Films)

# %%
vis1 = sns.lmplot (data = movies, x = 'CriticRating',y = 'AudianceRating',fit_reg= False)

# %%
plt.show()

# %%
vis1 = sns.lmplot (data = movies, x = 'CriticRating',y = 'AudianceRating',fit_reg= False,hue='Genre')

# %%
plt.show()

# %%
#vis1 = sns.lmplot (data = movies, x = 'CriticRating',y = 'AudianceRating',fit_reg= False,hue='Film')

# %%
#plt.show()

# %%
vis1 = sns.lmplot (data = movies, x = 'CriticRating',y = 'AudianceRating',fit_reg= False,hue='Genre', height= 10,aspect = 1)

# %%
plt.show()

# %% [markdown]
# KDE PLOT

# %%
k1 = sns.kdeplot(movies.CriticRating)

# %%
plt.show()

# %%
h1 =plt.hist(movies.CriticRating)

# %%
plt.show()

# %%
k1 = sns.kdeplot(movies.CriticRating,movies.AudianceRating)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 k1 = sns.kdeplot(movies.CriticRating,movies.AudianceRating)
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 were given

# %%
k1 = sns.kdeplot(movies.CriticRating,movies.AudianceRating)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 k1 = sns.kdeplot(movies.CriticRating,movies.AudianceRating)
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 were given

# %%
k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudianceRating')

# %%
plt.show()

# %%
k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudianceRating',shade = True,shade_lowest = False,cmap = 'Reds')

# %%
plt.show()

# %%
h2 = sns.lmplot( data = movies ,x= 'CriticRating' , y = 'AudianceRating')
plt.show()

# %%
k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudianceRating',shade_lowest = False,cmap = 'Reds')

# %%
plt.show()

# %% [markdown]
# The provided Python code uses the `seaborn` library to create a 2D Kernel Density Estimate (KDE) plot.
#
# Here is a breakdown of the code:
#
# * `sns.kdeplot()`: This is the function used to create the KDE plot. It estimates and visualizes the probability density of the data.
# * `data=movies`: The data used for the plot is taken from a DataFrame named `movies`.
# * `x='CriticRating'`: The values from the 'CriticRating' column are plotted on the x-axis.
# * `y='AudianceRating'`: The values from the 'AudianceRating' column are plotted on the y-axis.
# * `shade_lowest=False`: This parameter prevents the lowest density area (the lowest contour line) from being shaded.
# * `cmap='Reds'`: This specifies that the plot will use the 'Reds' colormap. The plot will use different shades of red to represent the density of the data points, with darker reds indicating a higher density.

# %%
k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudianceRating',shade_lowest = False,cmap = 'Greens')

# %%
plt.show()

# %%
sns.set_style('dark') # it means the back ground colour is black
k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudianceRating',shade_lowest = False,cmap = 'Greens')

# %%
plt.show()

# %%
sns.set_style( 'darkgrid')
k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudianceRating')

# %%
plt.show()

# %%
sns.set_style('dark')
k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudianceRating')

# %%
plt.show()

# %%
k2 = sns.kdeplot(data = movies,x = 'BudgetMillions' , y = 'CriticRating')

# %%
plt.show()

# %% [markdown]
# Subplot in matplotlib

# %%
ax = plt.subplots(1,2,figsize = (12,6))
plt.show()

# %%
# Box plots
w = sns.boxplot(data = movies, x ='Genre', y = 'CriticRating')

# %%
plt.show()
